# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_lg")

# %%
hints = pd.read_csv("hints_common.csv", index_col=[0])
hints.sort_values('2020', ascending=False)[30:70]
# Out:
#              1994   1995   1996   1997   1998   1999   2000   2001   2002  \
# name        226.0  159.0  255.0  269.0  247.0  219.0  233.0  218.0  193.0
# who          53.0   54.0   71.0   97.0   93.0  126.0  141.0  140.0  151.0
# at          188.0  141.0  190.0  232.0  210.0  233.0  214.0  211.0  236.0
# what         61.0   60.0   98.0  103.0  121.0  118.0  125.0  154.0  165.0
# e.g.        397.0  396.0  461.0  443.0  435.0  389.0  444.0  408.0  379.0
# you          96.0   84.0  101.0  113.0  129.0  131.0  140.0  169.0  140.0
# short       123.0  101.0  148.0  147.0  144.0  146.0  131.0  115.0  159.0
# ...         108.0  138.0  127.0  123.0  111.0  125.0  134.0  125.0  179.0
# up          229.0  228.0  249.0  239.0  263.0  295.0  269.0  302.0  291.0
# do          128.0  126.0  143.0  170.0  219.0  202.0  234.0  215.0  238.0
# by          105.0   86.0  109.0   93.0  120.0  152.0  136.0  150.0  152.0
# go          133.0   97.0  127.0  171.0  162.0  186.0  191.0  200.0  203.0
# ...

# %%
stop_words = ['\"', '_', ';', 'of', 'a', 'the', 'in', 'for', 'be', 'to', 'with', 'and',
                 'on', 'one', 'it', 'that', 'as', 'by', 'or', 'what', 'from', 
                  'at', 'out']

# %%
w = ['informally', 'something', 'maybe']

fig, ax = plt.subplots(figsize = (8,8))

for word in w:
    ax.plot(range(1994,2021), hints.loc[word], 'o-', label=word)

ax.set_xlabel("Year", fontsize = 14)
ax.set_ylabel("Occurances", fontsize = 14)


ax.legend(fontsize=14)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
